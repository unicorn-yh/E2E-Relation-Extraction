# %%
import os,sys
import csv
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages

# Constants
MR_FIELDS = ["name", "familyFriendly", "eatType", "food", "priceRange", "near", "area", "customer rating"]
MR_KEYMAP = dict((key, idx) for idx, key in enumerate(MR_FIELDS))
MR_KEY_NUM = len(MR_KEYMAP)

# Mappngs for delexicalization
NAME_TOKEN = '<name>'
NEAR_TOKEN = '<near>'
PAD_TOKEN = '<blank>'
PAD_ID = 0

# Regex pattern for tokenization
_WORD_SPLIT = re.compile(r"([.,!?\"':;)(])")

# Misc
FOOD_TYPE_PAT = re.compile(r'food\[(.*?)\]')
JAP_CUISINE = set(['sushi', 'sushi.', 'asian', 'oriental'])

# %%
# %matplotlib
pd.options.display.max_seq_items = 2000
pd.set_option('max_colwidth', 200)
# Out:
# Using matplotlib backend: TkAgg

# %%
def process_e2e_text(s):
    # Process E2E Challenge reference texts
    # Represent each references as a list of tokens.
    words = []
    for fragment in s.strip().split():
        fragment_tokens = _WORD_SPLIT.split(fragment)
        words.extend(fragment_tokens)
    tokens = [w for w in words if w]
    return tokens

# %%
def process_e2e_mr(s):
    # Process E2E Challenge meaning representation
    # Represent each MR as a list of 8 attributes, specified in 'MR_FIELDS'
    items = s.split(", ")
    mr_data = [None] * MR_KEY_NUM
    for idx, item in enumerate(items):
        key, raw_val = item.split("[")
        key_idx = MR_KEYMAP[key]
        mr_data[key_idx] = raw_val[:-1]
    return dict(zip(MR_FIELDS,mr_data))

# %%
def process_e2e_mr_delex(s):
    # Process E2E Challenge meaning representation w/ 'name' and 'near' delexicalized
    # Represent each MR as a list of 8 attributes, specified in 'MR_FIELDS'
    items = s.split(", ")
    mr_data = [None] * MR_KEY_NUM
    lex = [None, None] # holds lexicalized variants of NAME and NEAR
    for idx, item in enumerate(items):
        key, raw_val = item.split("[")
        key_idx = MR_KEYMAP[key]
        # Delexicalization
        if key == 'name':
            mr_val = NAME_TOKEN
            lex[0] = raw_val[:-1]
        elif key == 'near':
            mr_val = NEAR_TOKEN
            lex[1] = raw_val[:-1]
        else:
            mr_val = raw_val[:-1]
        mr_data[key_idx] = mr_val
    return dict(zip(MR_FIELDS,mr_data))


def cnt_bins_and_cnts():
    # Aux function to compute exact number of snt lengths
    lengths_to_consider = [0,10,20,30,40,50,60,70,80]
    bins = [(lengths_to_consider[i], lengths_to_consider[i+1]) for i in range(len(lengths_to_consider)-1)]
    cnts = [0] * len(bins)
    for l in references_lens:
        for bin_idx, b in enumerate(bins):
            if l > b[0] and l <= b[1]:
                cnts[bin_idx] += 1
                break
    return (bins, cnts)

def plot_len_hist(lens, fname):
    # Aux function to plot a histogram of the distribution of lengths of references.
    # Creating a Pandas DataFrame from a list of lengths 
    references_lens_df = pd.DataFrame(references_lens)
    # Retrieving stats from Pandas DF
    mean = float(references_lens_df.mean())
    std = float (references_lens_df.std())
    min_len = int(references_lens_df.min())
    max_len = int(references_lens_df.max())
    
    pp = PdfPages(fname)
    # plot the histogram of the length distribution
    n, bins, patches = plt.hist(lens, 20, facecolor='b', alpha=0.55)
    plt.xlabel('Sentence Length')
    plt.ylabel('Number of sentences')
    plt.title('Sentence length distribution')
    plt.axis([0, 80, 0, 10000])
    
    plt.text(40, 7500, r'$mean={:.2f},\ std={:.2f}$'.format(mean, std))
    plt.text(40, 6800, r'$min={},\ max={}$'.format(min_len, max_len))
    
    plt.grid(True)
    plt.tight_layout()
    plt.show()
    pp.savefig()
    pp.close()

# %%
FNAME = os.path.abspath("e2e_dataset/trainset.csv") # fname of the training data
DATA_LEN_HIST_FN = 'data_len_hist.pdf' #fname for the histogram of length distribution
data = pd.read_csv(FNAME,dtype=str) # Pandas DataFrame obj holding data

# %%
mr_dict = [process_e2e_mr(data.iloc[i]['mr']) for i in range(len(data))]
mr_dict
# Out:
# [{'name': 'The Vaults',
#   'familyFriendly': None,
#   'eatType': 'pub',
#   'food': None,
#   'priceRange': 'more than £30',
#   'near': 'Café Adriatic',
#   'area': None,
#   'customer rating': '5 out of 5'},
#  {'name': 'The Cambridge Blue',
#   'familyFriendly': None,
#   'eatType': 'pub',
#   'food': 'English',
#   'priceRange': 'cheap',
#   'near': 'Café Brazil',
#   'area': None,
#   'customer rating': None},
#  {'name': 'The Eagle',
#   'familyFriendly': 'yes',
#   'eatType': 'coffee shop',
#   'food': 'Japanese',
#   'priceRange': 'less than £20',
#   'near': 'Burger King',
#   'area': 'riverside',
#   'customer rating': 'low'},
#  {'name': 'The Mill',
#   'familyFriendly': None,
#   'eatType': 'coffee shop',
#   'food': 'French',
#   'priceRange': '£20-25',
#   'near': 'The Sorrento',
#   'area': 'riverside',
#   'customer rating': None},
#  {'name': 'Loch Fyne',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': 'French',
#   'priceRange': None,
#   'near': 'The Rice Boat',
#   'area': 'riverside',
#   'customer rating': 'high'},
#  {'name': 'Bibimbap House',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': 'English',
#   'priceRange': 'moderate',
#   'near': 'Clare Hall',
#   'area': 'riverside',
#   'customer rating': None},
#  {'name': 'The Rice Boat',
#   'familyFriendly': 'no',
#   'eatType': None,
#   'food': 'French',
#   'priceRange': None,
#   'near': None,
#   'area': 'riverside',
#   'customer rating': 'average'},
#  {'name': 'The Wrestlers',
#   'familyFriendly': 'no',
#   'eatType': 'coffee shop',
#   'food': 'Japanese',
#   'priceRange': 'less than £20',
#   'near': 'Raja Indian Cuisine',
#   'area': 'riverside',
#   'customer rating': None},
#  {'name': 'Aromi',
#   'familyFriendly': 'no',
#   'eatType': 'coffee shop',
#   'food': 'French',
#   'priceRange': None,
#   'near': None,
#   'area': 'city centre',
#   'customer rating': 'low'},
#  {'name': 'The Phoenix',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': 'Fast food',
#   'priceRange': 'moderate',
#   'near': None,
#   'area': 'riverside',
#   'customer rating': '3 out of 5'},
#  {'name': 'Browns Cambridge',
#   'familyFriendly': 'no',
#   'eatType': None,
#   'food': 'Fast food',
#   'priceRange': None,
#   'near': 'The Sorrento',
#   'area': 'riverside',
#   'customer rating': None},
#  {'name': 'Loch Fyne',
#   'familyFriendly': 'yes',
#   'eatType': 'restaurant',
#   'food': 'English',
#   'priceRange': None,
#   'near': None,
#   'area': None,
#   'customer rating': None},
#  {'name': 'Taste of Cambridge',
#   'familyFriendly': None,
#   'eatType': 'restaurant',
#   'food': None,
#   'priceRange': '£20-25',
#   'near': None,
#   'area': None,
#   'customer rating': '3 out of 5'},
#  {'name': 'Cocum',
#   'familyFriendly': 'yes',
#   'eatType': 'coffee shop',
#   'food': 'Italian',
#   'priceRange': 'cheap',
#   'near': None,
#   'area': None,
#   'customer rating': 'average'},
#  {'name': 'The Dumpling Tree',
#   'familyFriendly': None,
#   'eatType': 'restaurant',
#   'food': 'Italian',
#   'priceRange': 'high',
#   'near': None,
#   'area': None,
#   'customer rating': None},
#  {'name': 'The Punter',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': 'Indian',
#   'priceRange': 'cheap',
#   'near': None,
#   'area': None,
#   'customer rating': None},
#  {'name': 'The Golden Curry',
#   'familyFriendly': 'yes',
#   'eatType': None,
#   'food': 'English',
#   'priceRange': None,
#   'near': 'Café Rouge',
#   'area': 'riverside',
#   'customer rating': '5 out of 5'},
#  {'name': 'The Phoenix',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': 'English',
#   'priceRange': 'high',
#   'near': None,
#   'area': 'city centre',
#   'customer rating': '1 out of 5'},
#  {'name': 'Alimentum',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': 'Fast food',
#   'priceRange': '£20-25',
#   'near': 'Yippee Noodle Bar',
#   'area': 'city centre',
#   'customer rating': 'high'},
#  {'name': 'The Eagle',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': 'Chinese',
#   'priceRange': None,
#   'near': None,
#   'area': None,
#   'customer rating': '1 out of 5'},
#  {'name': 'The Punter',
#   'familyFriendly': 'yes',
#   'eatType': None,
#   'food': None,
#   'priceRange': 'less than £20',
#   'near': 'The Portland Arms',
#   'area': 'city centre',
#   'customer rating': None},
#  {'name': 'The Mill',
#   'familyFriendly': None,
#   'eatType': 'coffee shop',
#   'food': 'Italian',
#   'priceRange': 'more than £30',
#   'near': 'The Sorrento',
#   'area': 'riverside',
#   'customer rating': None},
#  {'name': 'Midsummer House',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': 'Italian',
#   'priceRange': 'moderate',
#   'near': 'All Bar One',
#   'area': None,
#   'customer rating': '3 out of 5'},
#  {'name': 'The Rice Boat',
#   'familyFriendly': 'yes',
#   'eatType': None,
#   'food': 'English',
#   'priceRange': '£20-25',
#   'near': 'Express by Holiday Inn',
#   'area': 'riverside',
#   'customer rating': 'high'},
#  {'name': 'Blue Spice',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': 'French',
#   'priceRange': 'more than £30',
#   'near': None,
#   'area': 'riverside',
#   'customer rating': None},
#  {'name': 'Strada',
#   'familyFriendly': None,
#   'eatType': 'pub',
#   'food': 'Italian',
#   'priceRange': None,
#   'near': 'Yippee Noodle Bar',
#   'area': None,
#   'customer rating': '5 out of 5'},
#  {'name': 'Alimentum',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': 'Chinese',
#   'priceRange': 'high',
#   'near': 'Yippee Noodle Bar',
#   'area': 'riverside',
#   'customer rating': 'average'},
#  {'name': 'The Cambridge Blue',
#   'familyFriendly': None,
#   'eatType': 'pub',
#   'food': 'Chinese',
#   'priceRange': '£20-25',
#   'near': 'Café Brazil',
#   'area': None,
#   'customer rating': None},
#  {'name': 'The Waterman',
#   'familyFriendly': None,
#   'eatType': 'pub',
#   'food': 'Fast food',
#   'priceRange': None,
#   'near': None,
#   'area': 'riverside',
#   'customer rating': '5 out of 5'},
#  {'name': 'Bibimbap House',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': 'English',
#   'priceRange': 'less than £20',
#   'near': 'Clare Hall',
#   'area': 'riverside',
#   'customer rating': None},
#  {'name': 'Zizzi',
#   'familyFriendly': 'yes',
#   'eatType': 'pub',
#   'food': 'French',
#   'priceRange': None,
#   'near': None,
#   'area': None,
#   'customer rating': '3 out of 5'},
#  {'name': 'Alimentum',
#   'familyFriendly': 'no',
#   'eatType': None,
#   'food': 'Italian',
#   'priceRange': 'less than £20',
#   'near': None,
#   'area': 'riverside',
#   'customer rating': None},
#  {'name': 'The Wrestlers',
#   'familyFriendly': 'yes',
#   'eatType': 'coffee shop',
#   'food': 'Italian',
#   'priceRange': 'more than £30',
#   'near': 'Raja Indian Cuisine',
#   'area': 'riverside',
#   'customer rating': None},
#  {'name': 'The Golden Curry',
#   'familyFriendly': 'no',
#   'eatType': None,
#   'food': 'English',
#   'priceRange': 'high',
#   'near': 'The Bakers',
#   'area': None,
#   'customer rating': None},
#  {'name': 'Green Man',
#   'familyFriendly': 'no',
#   'eatType': None,
#   'food': 'French',
#   'priceRange': 'more than £30',
#   'near': 'All Bar One',
#   'area': 'city centre',
#   'customer rating': None},
#  {'name': 'The Waterman',
#   'familyFriendly': 'no',
#   'eatType': None,
#   'food': None,
#   'priceRange': 'less than £20',
#   'near': None,
#   'area': None,
#   'customer rating': None},
#  {'name': 'Zizzi',
#   'familyFriendly': None,
#   'eatType': 'restaurant',
#   'food': None,
#   'priceRange': 'more than £30',
#   'near': None,
#   'area': 'riverside',
#   'customer rating': None},
#  {'name': 'The Golden Curry',
#   'familyFriendly': 'no',
#   'eatType': None,
#   'food': 'Indian',
#   'priceRange': None,
#   'near': 'Café Rouge',
#   'area': 'riverside',
#   'customer rating': 'average'},
#  {'name': 'The Dumpling Tree',
#   'familyFriendly': None,
#   'eatType': 'restaurant',
#   'food': 'Japanese',
#   'priceRange': 'more than £30',
#   'near': None,
#   'area': None,
#   'customer rating': None},
#  {'name': 'The Punter',
#   'familyFriendly': 'yes',
#   'eatType': 'coffee shop',
#   'food': 'Japanese',
#   'priceRange': 'less than £20',
#   'near': 'Café Sicilia',
#   'area': None,
#   'customer rating': 'low'},
#  {'name': 'Clowns',
#   'familyFriendly': None,
#   'eatType': 'coffee shop',
#   'food': 'Italian',
#   'priceRange': None,
#   'near': 'Clare Hall',
#   'area': 'riverside',
#   'customer rating': 'average'},
#  {'name': 'The Dumpling Tree',
#   'familyFriendly': 'no',
#   'eatType': 'pub',
#   'food': 'Japanese',
#   'priceRange': None,
#   'near': 'The Portland Arms',
#   'area': None,
#   'customer rating': None},
#  {'name': 'Blue Spice',
#   'familyFriendly': 'no',
#   'eatType': 'coffee shop',
#   'food': None,
#   'priceRange': 'more than £30',
#   'near': 'Avalon',
#   'area': 'riverside',
#   'customer rating': 'low'},
#  {'name': 'Giraffe',
#   'familyFriendly': 'yes',
#   'eatType': 'pub',
#   'food': 'Fast food',
#   'priceRange': None,
#   'near': None,
#   'area': 'riverside',
#   'customer rating': None},
#  {'name': 'Browns Cambridge',
#   'familyFriendly': 'yes',
#   'eatType': None,
#   'food': 'English',
#   'priceRange': None,
#   'near': 'The Sorrento',
#   'area': 'riverside',
#   'customer rating': None},
#  {'name': 'Cocum',
#   'familyFriendly': 'yes',
#   'eatType': 'coffee shop',
#   'food': 'Italian',
#   'priceRange': '£20-25',
#   'near': None,
#   'area': None,
#   'customer rating': 'high'},
#  {'name': 'The Punter',
#   'familyFriendly': 'yes',
#   'eatType': 'coffee shop',
#   'food': 'Italian',
#   'priceRange': 'cheap',
#   'near': 'Café Sicilia',
#   'area': None,
#   'customer rating': 'average'},
#  {'name': 'The Olive Grove',
#   'familyFriendly': 'no',
#   'eatType': 'pub',
#   'food': 'Indian',
#   'priceRange': 'moderate',
#   'near': None,
#   'area': 'riverside',
#   'customer rating': None},
#  {'name': 'Giraffe',
#   'familyFriendly': None,
#   'eatType': 'restaurant',
#   'food': None,
#   'priceRange': 'more than £30',
#   'near': 'The Six Bells',
#   'area': None,
#   'customer rating': None},
#  {'name': 'Cocum',
#   'familyFriendly': 'yes',
#   'eatType': 'restaurant',
#   'food': None,
#   'priceRange': None,
#   'near': None,
#   'area': None,
#   'customer rating': '3 out of 5'},
#  {'name': 'The Twenty Two',
#   'familyFriendly': 'yes',
#   'eatType': None,
#   'food': 'Italian',
#   'priceRange': None,
#   'near': None,
#   'area': None,
#   'customer rating': None},
#  {'name': 'The Cricketers',
#   'familyFriendly': 'yes',
#   'eatType': 'pub',
#   'food': None,
#   'priceRange': None,
#   'near': 'Ranch',
#   'area': None,
#   'customer rating': '5 out of 5'},
#  {'name': 'The Eagle',
#   'familyFriendly': 'yes',
#   'eatType': 'coffee shop',
#   'food': 'French',
#   'priceRange': 'more than £30',
#   'near': 'Burger King',
#   'area': 'riverside',
#   'customer rating': '5 out of 5'},
#  {'name': 'Blue Spice',
#   'familyFriendly': 'yes',
#   'eatType': 'coffee shop',
#   'food': None,
#   'priceRange': 'cheap',
#   'near': 'Avalon',
#   'area': 'riverside',
#   'customer rating': 'average'},
#  {'name': 'Browns Cambridge',
#   'familyFriendly': 'no',
#   'eatType': 'coffee shop',
#   'food': 'French',
#   'priceRange': None,
#   'near': 'Crowne Plaza Hotel',
#   'area': 'city centre',
#   'customer rating': 'average'},
#  {'name': 'The Golden Curry',
#   'familyFriendly': 'yes',
#   'eatType': None,
#   'food': 'Indian',
#   'priceRange': None,
#   'near': 'Café Rouge',
#   'area': 'riverside',
#   'customer rating': '3 out of 5'},
#  {'name': 'Wildwood',
#   'familyFriendly': None,
#   'eatType': 'pub',
#   'food': 'Italian',
#   'priceRange': 'high',
#   'near': None,
#   'area': None,
#   'customer rating': '1 out of 5'},
#  {'name': 'The Golden Curry',
#   'familyFriendly': 'yes',
#   'eatType': None,
#   'food': 'Italian',
#   'priceRange': 'less than £20',
#   'near': 'The Bakers',
#   'area': None,
#   'customer rating': None},
#  {'name': 'The Rice Boat',
#   'familyFriendly': 'yes',
#   'eatType': None,
#   'food': 'Italian',
#   'priceRange': None,
#   'near': None,
#   'area': 'riverside',
#   'customer rating': 'low'},
#  {'name': 'Strada',
#   'familyFriendly': 'yes',
#   'eatType': None,
#   'food': 'Chinese',
#   'priceRange': 'less than £20',
#   'near': 'Rainbow Vegetarian Café',
#   'area': None,
#   'customer rating': 'low'},
#  {'name': 'Alimentum',
#   'familyFriendly': 'no',
#   'eatType': None,
#   'food': 'Fast food',
#   'priceRange': 'less than £20',
#   'near': None,
#   'area': 'city centre',
#   'customer rating': None},
#  {'name': 'Blue Spice',
#   'familyFriendly': 'yes',
#   'eatType': None,
#   'food': None,
#   'priceRange': 'cheap',
#   'near': None,
#   'area': 'riverside',
#   'customer rating': 'average'},
#  {'name': 'Alimentum',
#   'familyFriendly': 'yes',
#   'eatType': None,
#   'food': 'Fast food',
#   'priceRange': 'more than £30',
#   'near': None,
#   'area': 'riverside',
#   'customer rating': None},
#  {'name': 'The Golden Palace',
#   'familyFriendly': None,
#   'eatType': 'coffee shop',
#   'food': 'Italian',
#   'priceRange': 'cheap',
#   'near': None,
#   'area': 'city centre',
#   'customer rating': '5 out of 5'},
#  {'name': 'Loch Fyne',
#   'familyFriendly': 'yes',
#   'eatType': 'restaurant',
#   'food': 'Chinese',
#   'priceRange': None,
#   'near': None,
#   'area': None,
#   'customer rating': None},
#  {'name': 'The Cricketers',
#   'familyFriendly': 'yes',
#   'eatType': 'coffee shop',
#   'food': 'Fast food',
#   'priceRange': None,
#   'near': 'The Portland Arms',
#   'area': None,
#   'customer rating': '5 out of 5'},
#  {'name': 'Cocum',
#   'familyFriendly': 'no',
#   'eatType': 'coffee shop',
#   'food': 'Japanese',
#   'priceRange': 'more than £30',
#   'near': None,
#   'area': None,
#   'customer rating': 'low'},
#  {'name': 'Browns Cambridge',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': 'Fast food',
#   'priceRange': 'moderate',
#   'near': None,
#   'area': None,
#   'customer rating': '1 out of 5'},
#  {'name': 'The Golden Palace',
#   'familyFriendly': None,
#   'eatType': 'coffee shop',
#   'food': 'Fast food',
#   'priceRange': 'cheap',
#   'near': None,
#   'area': 'riverside',
#   'customer rating': '5 out of 5'},
#  {'name': 'The Waterman',
#   'familyFriendly': 'yes',
#   'eatType': None,
#   'food': 'English',
#   'priceRange': 'more than £30',
#   'near': None,
#   'area': 'city centre',
#   'customer rating': 'high'},
#  {'name': 'Loch Fyne',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': 'Indian',
#   'priceRange': None,
#   'near': 'The Rice Boat',
#   'area': 'city centre',
#   'customer rating': 'average'},
#  {'name': 'The Golden Curry',
#   'familyFriendly': 'no',
#   'eatType': None,
#   'food': 'Italian',
#   'priceRange': None,
#   'near': 'Café Rouge',
#   'area': 'city centre',
#   'customer rating': '5 out of 5'},
#  {'name': 'Blue Spice',
#   'familyFriendly': 'no',
#   'eatType': None,
#   'food': None,
#   'priceRange': '£20-25',
#   'near': None,
#   'area': 'riverside',
#   'customer rating': '3 out of 5'},
#  {'name': 'The Olive Grove',
#   'familyFriendly': 'yes',
#   'eatType': 'pub',
#   'food': 'French',
#   'priceRange': 'less than £20',
#   'near': None,
#   'area': 'riverside',
#   'customer rating': None},
#  {'name': 'Giraffe',
#   'familyFriendly': 'yes',
#   'eatType': 'coffee shop',
#   'food': None,
#   'priceRange': 'moderate',
#   'near': 'The Bakers',
#   'area': None,
#   'customer rating': '3 out of 5'},
#  {'name': 'Blue Spice',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': 'Japanese',
#   'priceRange': 'moderate',
#   'near': None,
#   'area': 'riverside',
#   'customer rating': None},
#  {'name': 'The Cambridge Blue',
#   'familyFriendly': None,
#   'eatType': 'restaurant',
#   'food': 'Chinese',
#   'priceRange': None,
#   'near': None,
#   'area': None,
#   'customer rating': 'high'},
#  {'name': 'The Waterman',
#   'familyFriendly': 'yes',
#   'eatType': None,
#   'food': 'French',
#   'priceRange': 'cheap',
#   'near': None,
#   'area': 'riverside',
#   'customer rating': '5 out of 5'},
#  {'name': 'The Golden Palace',
#   'familyFriendly': None,
#   'eatType': 'coffee shop',
#   'food': 'Italian',
#   'priceRange': 'high',
#   'near': None,
#   'area': 'riverside',
#   'customer rating': 'average'},
#  {'name': 'The Waterman',
#   'familyFriendly': 'yes',
#   'eatType': None,
#   'food': 'Italian',
#   'priceRange': None,
#   'near': 'Crowne Plaza Hotel',
#   'area': None,
#   'customer rating': None},
#  {'name': 'Blue Spice',
#   'familyFriendly': 'no',
#   'eatType': None,
#   'food': None,
#   'priceRange': '£20-25',
#   'near': None,
#   'area': 'riverside',
#   'customer rating': '3 out of 5'},
#  {'name': 'Midsummer House',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': 'Italian',
#   'priceRange': 'high',
#   'near': 'All Bar One',
#   'area': None,
#   'customer rating': 'average'},
#  {'name': 'The Rice Boat',
#   'familyFriendly': 'yes',
#   'eatType': None,
#   'food': 'Italian',
#   'priceRange': 'moderate',
#   'near': 'Express by Holiday Inn',
#   'area': 'city centre',
#   'customer rating': '3 out of 5'},
#  {'name': 'Strada',
#   'familyFriendly': 'yes',
#   'eatType': None,
#   'food': 'Japanese',
#   'priceRange': 'more than £30',
#   'near': 'Rainbow Vegetarian Café',
#   'area': None,
#   'customer rating': 'low'},
#  {'name': 'The Olive Grove',
#   'familyFriendly': 'yes',
#   'eatType': 'pub',
#   'food': 'English',
#   'priceRange': 'moderate',
#   'near': None,
#   'area': 'riverside',
#   'customer rating': None},
#  {'name': 'The Phoenix',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': 'Fast food',
#   'priceRange': None,
#   'near': None,
#   'area': 'city centre',
#   'customer rating': 'low'},
#  {'name': 'Clowns',
#   'familyFriendly': None,
#   'eatType': 'pub',
#   'food': None,
#   'priceRange': 'high',
#   'near': None,
#   'area': 'riverside',
#   'customer rating': '3 out of 5'},
#  {'name': 'Green Man',
#   'familyFriendly': 'yes',
#   'eatType': None,
#   'food': 'Japanese',
#   'priceRange': '£20-25',
#   'near': 'All Bar One',
#   'area': 'riverside',
#   'customer rating': None},
#  {'name': 'The Wrestlers',
#   'familyFriendly': 'yes',
#   'eatType': 'coffee shop',
#   'food': 'Italian',
#   'priceRange': 'moderate',
#   'near': 'Raja Indian Cuisine',
#   'area': 'riverside',
#   'customer rating': None},
#  {'name': 'The Golden Curry',
#   'familyFriendly': 'yes',
#   'eatType': None,
#   'food': 'English',
#   'priceRange': None,
#   'near': None,
#   'area': None,
#   'customer rating': 'low'},
#  {'name': 'The Rice Boat',
#   'familyFriendly': 'no',
#   'eatType': None,
#   'food': 'English',
#   'priceRange': None,
#   'near': None,
#   'area': 'riverside',
#   'customer rating': '5 out of 5'},
#  {'name': 'The Cambridge Blue',
#   'familyFriendly': None,
#   'eatType': 'restaurant',
#   'food': 'English',
#   'priceRange': None,
#   'near': None,
#   'area': None,
#   'customer rating': '5 out of 5'},
#  {'name': 'The Golden Palace',
#   'familyFriendly': None,
#   'eatType': 'restaurant',
#   'food': None,
#   'priceRange': 'cheap',
#   'near': None,
#   'area': None,
#   'customer rating': None},
#  {'name': 'Midsummer House',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': 'Indian',
#   'priceRange': None,
#   'near': 'Café Rouge',
#   'area': None,
#   'customer rating': 'low'},
#  {'name': 'Alimentum',
#   'familyFriendly': 'no',
#   'eatType': None,
#   'food': 'English',
#   'priceRange': 'high',
#   'near': None,
#   'area': 'riverside',
#   'customer rating': None},
#  {'name': 'Clowns',
#   'familyFriendly': None,
#   'eatType': 'coffee shop',
#   'food': 'Japanese',
#   'priceRange': None,
#   'near': 'Clare Hall',
#   'area': 'riverside',
#   'customer rating': '5 out of 5'},
#  {'name': 'The Rice Boat',
#   'familyFriendly': 'yes',
#   'eatType': None,
#   'food': 'English',
#   'priceRange': '£20-25',
#   'near': 'Express by Holiday Inn',
#   'area': 'riverside',
#   'customer rating': 'high'},
#  {'name': 'The Waterman',
#   'familyFriendly': 'no',
#   'eatType': None,
#   'food': 'Italian',
#   'priceRange': 'less than £20',
#   'near': None,
#   'area': 'city centre',
#   'customer rating': 'low'},
#  {'name': 'The Plough',
#   'familyFriendly': 'no',
#   'eatType': 'pub',
#   'food': 'Italian',
#   'priceRange': 'high',
#   'near': 'Café Rouge',
#   'area': None,
#   'customer rating': None},
#  {'name': 'The Phoenix',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': 'Chinese',
#   'priceRange': 'cheap',
#   'near': None,
#   'area': 'riverside',
#   'customer rating': 'average'},
#  {'name': 'Bibimbap House',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': 'Italian',
#   'priceRange': 'more than £30',
#   'near': 'Clare Hall',
#   'area': 'riverside',
#   'customer rating': None},
#  {'name': 'Loch Fyne',
#   'familyFriendly': 'no',
#   'eatType': 'restaurant',
#   'food': 'Fast food',
#   'priceRange': None,
#   'near': None,
#   'area': None,
#   'customer rating': None},
#  {'name': 'The Phoenix',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': 'French',
#   'priceRange': 'high',
#   'near': None,
#   'area': 'riverside',
#   'customer rating': '3 out of 5'},
#  {'name': 'Blue Spice',
#   'familyFriendly': 'yes',
#   'eatType': 'coffee shop',
#   'food': None,
#   'priceRange': 'cheap',
#   'near': 'Avalon',
#   'area': 'riverside',
#   'customer rating': 'average'},
#  {'name': 'The Rice Boat',
#   'familyFriendly': 'yes',
#   'eatType': None,
#   'food': 'Japanese',
#   'priceRange': None,
#   'near': None,
#   'area': 'city centre',
#   'customer rating': 'low'},
#  {'name': 'The Dumpling Tree',
#   'familyFriendly': 'yes',
#   'eatType': 'pub',
#   'food': 'Italian',
#   'priceRange': None,
#   'near': 'The Portland Arms',
#   'area': None,
#   'customer rating': None},
#  {'name': 'The Eagle',
#   'familyFriendly': 'yes',
#   'eatType': 'coffee shop',
#   'food': 'French',
#   'priceRange': 'more than £30',
#   'near': 'Burger King',
#   'area': 'riverside',
#   'customer rating': 'low'},
#  {'name': 'The Waterman',
#   'familyFriendly': 'no',
#   'eatType': None,
#   'food': 'French',
#   'priceRange': 'more than £30',
#   'near': None,
#   'area': 'city centre',
#   'customer rating': 'low'},
#  {'name': 'Clowns',
#   'familyFriendly': None,
#   'eatType': 'coffee shop',
#   'food': 'French',
#   'priceRange': None,
#   'near': 'Clare Hall',
#   'area': 'riverside',
#   'customer rating': '5 out of 5'},
#  {'name': 'Blue Spice',
#   'familyFriendly': 'no',
#   'eatType': 'coffee shop',
#   'food': None,
#   'priceRange': '£20-25',
#   'near': 'Avalon',
#   'area': 'city centre',
#   'customer rating': 'high'},
#  {'name': 'The Golden Palace',
#   'familyFriendly': None,
#   'eatType': 'coffee shop',
#   'food': 'Japanese',
#   'priceRange': 'more than £30',
#   'near': None,
#   'area': 'riverside',
#   'customer rating': '5 out of 5'},
#  {'name': 'Strada',
#   'familyFriendly': 'yes',
#   'eatType': None,
#   'food': 'English',
#   'priceRange': 'cheap',
#   'near': 'Rainbow Vegetarian Café',
#   'area': None,
#   'customer rating': 'average'},
#  {'name': 'The Waterman',
#   'familyFriendly': 'no',
#   'eatType': None,
#   'food': 'English',
#   'priceRange': None,
#   'near': 'Crowne Plaza Hotel',
#   'area': None,
#   'customer rating': None},
#  {'name': 'The Punter',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': 'English',
#   'priceRange': 'high',
#   'near': None,
#   'area': None,
#   'customer rating': None},
#  {'name': 'Cotto',
#   'familyFriendly': 'yes',
#   'eatType': None,
#   'food': 'Indian',
#   'priceRange': None,
#   'near': 'Ranch',
#   'area': None,
#   'customer rating': 'high'},
#  {'name': 'Browns Cambridge',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': 'Fast food',
#   'priceRange': 'high',
#   'near': None,
#   'area': None,
#   'customer rating': '3 out of 5'},
#  {'name': 'Strada',
#   'familyFriendly': None,
#   'eatType': 'pub',
#   'food': 'Italian',
#   'priceRange': None,
#   'near': 'Yippee Noodle Bar',
#   'area': None,
#   'customer rating': 'high'},
#  {'name': 'Blue Spice',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': 'Italian',
#   'priceRange': 'less than £20',
#   'near': None,
#   'area': 'riverside',
#   'customer rating': None},
#  {'name': 'The Rice Boat',
#   'familyFriendly': 'no',
#   'eatType': None,
#   'food': 'French',
#   'priceRange': None,
#   'near': None,
#   'area': 'city centre',
#   'customer rating': 'average'},
#  {'name': 'Browns Cambridge',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': 'English',
#   'priceRange': 'moderate',
#   'near': None,
#   'area': None,
#   'customer rating': '3 out of 5'},
#  {'name': 'Browns Cambridge',
#   'familyFriendly': 'yes',
#   'eatType': 'coffee shop',
#   'food': 'Indian',
#   'priceRange': None,
#   'near': 'Crowne Plaza Hotel',
#   'area': 'city centre',
#   'customer rating': '5 out of 5'},
#  {'name': 'The Wrestlers',
#   'familyFriendly': 'yes',
#   'eatType': 'coffee shop',
#   'food': 'Fast food',
#   'priceRange': 'moderate',
#   'near': 'Raja Indian Cuisine',
#   'area': 'riverside',
#   'customer rating': None},
#  {'name': 'Cocum',
#   'familyFriendly': 'yes',
#   'eatType': 'pub',
#   'food': None,
#   'priceRange': 'moderate',
#   'near': None,
#   'area': None,
#   'customer rating': '3 out of 5'},
#  {'name': 'The Olive Grove',
#   'familyFriendly': 'yes',
#   'eatType': 'pub',
#   'food': 'Indian',
#   'priceRange': '£20-25',
#   'near': None,
#   'area': 'riverside',
#   'customer rating': None},
#  {'name': 'Strada',
#   'familyFriendly': 'yes',
#   'eatType': None,
#   'food': 'Chinese',
#   'priceRange': 'less than £20',
#   'near': 'Rainbow Vegetarian Café',
#   'area': None,
#   'customer rating': 'low'},
#  {'name': 'The Golden Palace',
#   'familyFriendly': None,
#   'eatType': 'pub',
#   'food': None,
#   'priceRange': 'high',
#   'near': 'Rainbow Vegetarian Café',
#   'area': 'riverside',
#   'customer rating': None},
#  {'name': 'The Eagle',
#   'familyFriendly': 'yes',
#   'eatType': 'coffee shop',
#   'food': 'Italian',
#   'priceRange': 'high',
#   'near': 'Burger King',
#   'area': 'riverside',
#   'customer rating': 'average'},
#  {'name': 'Alimentum',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': 'French',
#   'priceRange': '£20-25',
#   'near': 'Yippee Noodle Bar',
#   'area': 'riverside',
#   'customer rating': 'high'},
#  {'name': 'Cotto',
#   'familyFriendly': None,
#   'eatType': 'coffee shop',
#   'food': 'Fast food',
#   'priceRange': 'high',
#   'near': 'The Portland Arms',
#   'area': 'riverside',
#   'customer rating': '1 out of 5'},
#  {'name': 'Alimentum',
#   'familyFriendly': 'yes',
#   'eatType': None,
#   'food': 'Chinese',
#   'priceRange': 'more than £30',
#   'near': None,
#   'area': 'riverside',
#   'customer rating': None},
#  {'name': 'The Rice Boat',
#   'familyFriendly': 'yes',
#   'eatType': None,
#   'food': 'English',
#   'priceRange': None,
#   'near': None,
#   'area': 'riverside',
#   'customer rating': '5 out of 5'},
#  {'name': 'The Eagle',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': 'English',
#   'priceRange': None,
#   'near': None,
#   'area': None,
#   'customer rating': '5 out of 5'},
#  {'name': 'Cocum',
#   'familyFriendly': 'yes',
#   'eatType': 'coffee shop',
#   'food': 'Fast food',
#   'priceRange': 'less than £20',
#   'near': None,
#   'area': None,
#   'customer rating': 'low'},
#  {'name': 'The Rice Boat',
#   'familyFriendly': 'yes',
#   'eatType': None,
#   'food': 'Chinese',
#   'priceRange': 'more than £30',
#   'near': 'Express by Holiday Inn',
#   'area': 'city centre',
#   'customer rating': 'high'},
#  {'name': 'The Golden Palace',
#   'familyFriendly': None,
#   'eatType': 'coffee shop',
#   'food': 'French',
#   'priceRange': 'less than £20',
#   'near': None,
#   'area': 'riverside',
#   'customer rating': 'low'},
#  {'name': 'The Olive Grove',
#   'familyFriendly': 'yes',
#   'eatType': 'pub',
#   'food': 'Italian',
#   'priceRange': 'moderate',
#   'near': None,
#   'area': 'riverside',
#   'customer rating': None},
#  {'name': 'Midsummer House',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': 'French',
#   'priceRange': None,
#   'near': 'Café Rouge',
#   'area': None,
#   'customer rating': 'low'},
#  {'name': 'The Golden Curry',
#   'familyFriendly': 'yes',
#   'eatType': None,
#   'food': 'English',
#   'priceRange': None,
#   'near': 'Café Rouge',
#   'area': 'city centre',
#   'customer rating': 'low'},
#  {'name': 'Zizzi',
#   'familyFriendly': 'no',
#   'eatType': 'pub',
#   'food': 'Italian',
#   'priceRange': None,
#   'near': None,
#   'area': None,
#   'customer rating': 'average'},
#  {'name': 'Loch Fyne',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': 'Chinese',
#   'priceRange': None,
#   'near': 'The Rice Boat',
#   'area': 'riverside',
#   'customer rating': '5 out of 5'},
#  {'name': 'The Dumpling Tree',
#   'familyFriendly': 'yes',
#   'eatType': 'coffee shop',
#   'food': None,
#   'priceRange': 'high',
#   'near': 'Café Sicilia',
#   'area': 'riverside',
#   'customer rating': None},
#  {'name': 'Browns Cambridge',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': 'Indian',
#   'priceRange': 'less than £20',
#   'near': None,
#   'area': None,
#   'customer rating': 'low'},
#  {'name': 'The Eagle',
#   'familyFriendly': 'no',
#   'eatType': 'coffee shop',
#   'food': 'French',
#   'priceRange': 'cheap',
#   'near': 'Burger King',
#   'area': 'city centre',
#   'customer rating': '5 out of 5'},
#  {'name': 'The Waterman',
#   'familyFriendly': None,
#   'eatType': 'pub',
#   'food': 'French',
#   'priceRange': None,
#   'near': None,
#   'area': 'riverside',
#   'customer rating': 'high'},
#  {'name': 'Alimentum',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': 'Fast food',
#   'priceRange': 'moderate',
#   'near': 'Yippee Noodle Bar',
#   'area': 'city centre',
#   'customer rating': '3 out of 5'},
#  {'name': 'The Eagle',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': None,
#   'priceRange': 'cheap',
#   'near': None,
#   'area': 'riverside',
#   'customer rating': '5 out of 5'},
#  {'name': 'Browns Cambridge',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': None,
#   'priceRange': 'moderate',
#   'near': None,
#   'area': None,
#   'customer rating': '3 out of 5'},
#  {'name': 'The Golden Palace',
#   'familyFriendly': None,
#   'eatType': 'coffee shop',
#   'food': 'Japanese',
#   'priceRange': 'moderate',
#   'near': None,
#   'area': 'riverside',
#   'customer rating': '1 out of 5'},
#  {'name': 'Alimentum',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': 'Fast food',
#   'priceRange': 'high',
#   'near': 'Yippee Noodle Bar',
#   'area': 'riverside',
#   'customer rating': '1 out of 5'},
#  {'name': 'The Golden Curry',
#   'familyFriendly': 'yes',
#   'eatType': None,
#   'food': 'Chinese',
#   'priceRange': 'less than £20',
#   'near': 'The Bakers',
#   'area': None,
#   'customer rating': None},
#  {'name': 'The Eagle',
#   'familyFriendly': 'yes',
#   'eatType': 'coffee shop',
#   'food': 'French',
#   'priceRange': 'cheap',
#   'near': 'Burger King',
#   'area': 'city centre',
#   'customer rating': '5 out of 5'},
#  {'name': 'Blue Spice',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': None,
#   'priceRange': '£20-25',
#   'near': None,
#   'area': 'riverside',
#   'customer rating': None},
#  {'name': 'The Mill',
#   'familyFriendly': None,
#   'eatType': 'coffee shop',
#   'food': 'Japanese',
#   'priceRange': 'more than £30',
#   'near': 'The Sorrento',
#   'area': 'riverside',
#   'customer rating': None},
#  {'name': 'Zizzi',
#   'familyFriendly': 'no',
#   'eatType': 'pub',
#   'food': 'Japanese',
#   'priceRange': None,
#   'near': None,
#   'area': None,
#   'customer rating': 'low'},
#  {'name': 'The Wrestlers',
#   'familyFriendly': 'no',
#   'eatType': None,
#   'food': 'Indian',
#   'priceRange': 'cheap',
#   'near': None,
#   'area': None,
#   'customer rating': 'average'},
#  {'name': 'Bibimbap House',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': 'Fast food',
#   'priceRange': 'moderate',
#   'near': 'Clare Hall',
#   'area': 'city centre',
#   'customer rating': None},
#  {'name': 'The Waterman',
#   'familyFriendly': None,
#   'eatType': 'pub',
#   'food': 'Italian',
#   'priceRange': None,
#   'near': None,
#   'area': 'city centre',
#   'customer rating': 'low'},
#  {'name': 'The Dumpling Tree',
#   'familyFriendly': None,
#   'eatType': 'restaurant',
#   'food': 'Indian',
#   'priceRange': 'more than £30',
#   'near': None,
#   'area': None,
#   'customer rating': None},
#  {'name': 'Fitzbillies',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': 'Italian',
#   'priceRange': 'cheap',
#   'near': 'The Six Bells',
#   'area': None,
#   'customer rating': None},
#  {'name': 'Zizzi',
#   'familyFriendly': 'yes',
#   'eatType': 'coffee shop',
#   'food': None,
#   'priceRange': '£20-25',
#   'near': None,
#   'area': 'riverside',
#   'customer rating': 'high'},
#  {'name': 'The Rice Boat',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': None,
#   'priceRange': 'less than £20',
#   'near': 'Rainbow Vegetarian Café',
#   'area': None,
#   'customer rating': 'low'},
#  {'name': 'The Dumpling Tree',
#   'familyFriendly': None,
#   'eatType': 'restaurant',
#   'food': 'English',
#   'priceRange': 'moderate',
#   'near': None,
#   'area': None,
#   'customer rating': None},
#  {'name': 'Strada',
#   'familyFriendly': 'no',
#   'eatType': None,
#   'food': 'French',
#   'priceRange': 'moderate',
#   'near': 'Rainbow Vegetarian Café',
#   'area': None,
#   'customer rating': '1 out of 5'},
#  {'name': 'The Eagle',
#   'familyFriendly': 'no',
#   'eatType': 'coffee shop',
#   'food': 'Indian',
#   'priceRange': 'moderate',
#   'near': 'Burger King',
#   'area': 'city centre',
#   'customer rating': '3 out of 5'},
#  {'name': 'The Olive Grove',
#   'familyFriendly': 'no',
#   'eatType': 'pub',
#   'food': None,
#   'priceRange': 'moderate',
#   'near': None,
#   'area': 'riverside',
#   'customer rating': None},
#  {'name': 'Browns Cambridge',
#   'familyFriendly': 'no',
#   'eatType': 'coffee shop',
#   'food': 'French',
#   'priceRange': None,
#   'near': 'Crowne Plaza Hotel',
#   'area': 'city centre',
#   'customer rating': 'average'},
#  {'name': 'Fitzbillies',
#   'familyFriendly': 'yes',
#   'eatType': None,
#   'food': None,
#   'priceRange': 'cheap',
#   'near': 'Express by Holiday Inn',
#   'area': None,
#   'customer rating': '5 out of 5'},
#  {'name': 'Cotto',
#   'familyFriendly': 'yes',
#   'eatType': None,
#   'food': 'French',
#   'priceRange': None,
#   'near': 'Ranch',
#   'area': None,
#   'customer rating': '1 out of 5'},
#  {'name': 'Loch Fyne',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': 'Italian',
#   'priceRange': None,
#   'near': 'The Rice Boat',
#   'area': 'riverside',
#   'customer rating': '5 out of 5'},
#  {'name': 'The Rice Boat',
#   'familyFriendly': 'no',
#   'eatType': None,
#   'food': 'Indian',
#   'priceRange': 'moderate',
#   'near': 'Express by Holiday Inn',
#   'area': 'city centre',
#   'customer rating': '3 out of 5'},
#  {'name': 'Zizzi',
#   'familyFriendly': 'no',
#   'eatType': 'coffee shop',
#   'food': None,
#   'priceRange': 'more than £30',
#   'near': None,
#   'area': 'riverside',
#   'customer rating': '5 out of 5'},
#  {'name': 'Strada',
#   'familyFriendly': None,
#   'eatType': 'pub',
#   'food': 'French',
#   'priceRange': None,
#   'near': 'Yippee Noodle Bar',
#   'area': None,
#   'customer rating': 'low'},
#  {'name': 'Alimentum',
#   'familyFriendly': 'no',
#   'eatType': None,
#   'food': 'Italian',
#   'priceRange': 'moderate',
#   'near': None,
#   'area': 'riverside',
#   'customer rating': None},
#  {'name': 'Browns Cambridge',
#   'familyFriendly': 'yes',
#   'eatType': 'coffee shop',
#   'food': 'Indian',
#   'priceRange': None,
#   'near': 'Crowne Plaza Hotel',
#   'area': 'city centre',
#   'customer rating': 'average'},
#  {'name': 'The Phoenix',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': 'French',
#   'priceRange': None,
#   'near': None,
#   'area': 'riverside',
#   'customer rating': 'low'},
#  {'name': 'Wildwood',
#   'familyFriendly': None,
#   'eatType': 'pub',
#   'food': 'Fast food',
#   'priceRange': '£20-25',
#   'near': None,
#   'area': None,
#   'customer rating': 'high'},
#  {'name': 'Clowns',
#   'familyFriendly': 'yes',
#   'eatType': None,
#   'food': None,
#   'priceRange': 'more than £30',
#   'near': 'Café Sicilia',
#   'area': None,
#   'customer rating': None},
#  {'name': 'Travellers Rest Beefeater',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': None,
#   'priceRange': 'more than £30',
#   'near': 'Café Adriatic',
#   'area': 'riverside',
#   'customer rating': '5 out of 5'},
#  {'name': 'The Mill',
#   'familyFriendly': None,
#   'eatType': 'pub',
#   'food': 'Chinese',
#   'priceRange': 'less than £20',
#   'near': None,
#   'area': 'riverside',
#   'customer rating': None},
#  {'name': 'Cotto',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': 'French',
#   'priceRange': None,
#   'near': 'Café Rouge',
#   'area': None,
#   'customer rating': None},
#  {'name': 'The Golden Curry',
#   'familyFriendly': 'no',
#   'eatType': None,
#   'food': 'Chinese',
#   'priceRange': None,
#   'near': None,
#   'area': None,
#   'customer rating': 'average'},
#  {'name': 'The Twenty Two',
#   'familyFriendly': 'yes',
#   'eatType': None,
#   'food': 'French',
#   'priceRange': None,
#   'near': None,
#   'area': None,
#   'customer rating': None},
#  {'name': 'The Phoenix',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': 'English',
#   'priceRange': None,
#   'near': None,
#   'area': 'riverside',
#   'customer rating': '5 out of 5'},
#  {'name': 'Cotto',
#   'familyFriendly': None,
#   'eatType': 'coffee shop',
#   'food': 'Fast food',
#   'priceRange': 'more than £30',
#   'near': 'The Portland Arms',
#   'area': 'city centre',
#   'customer rating': 'high'},
#  {'name': 'Fitzbillies',
#   'familyFriendly': 'yes',
#   'eatType': 'coffee shop',
#   'food': 'Fast food',
#   'priceRange': 'less than £20',
#   'near': None,
#   'area': 'riverside',
#   'customer rating': 'low'},
#  {'name': 'The Golden Palace',
#   'familyFriendly': None,
#   'eatType': 'coffee shop',
#   'food': 'Fast food',
#   'priceRange': 'less than £20',
#   'near': None,
#   'area': 'riverside',
#   'customer rating': 'low'},
#  {'name': 'The Waterman',
#   'familyFriendly': 'yes',
#   'eatType': None,
#   'food': None,
#   'priceRange': '£20-25',
#   'near': None,
#   'area': None,
#   'customer rating': None},
#  {'name': 'The Eagle',
#   'familyFriendly': 'no',
#   'eatType': 'coffee shop',
#   'food': 'Italian',
#   'priceRange': 'moderate',
#   'near': 'Burger King',
#   'area': 'city centre',
#   'customer rating': '1 out of 5'},
#  {'name': 'The Phoenix',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': 'Chinese',
#   'priceRange': None,
#   'near': None,
#   'area': 'riverside',
#   'customer rating': 'average'},
#  {'name': 'Loch Fyne',
#   'familyFriendly': 'yes',
#   'eatType': 'restaurant',
#   'food': 'Japanese',
#   'priceRange': 'less than £20',
#   'near': None,
#   'area': None,
#   'customer rating': None},
#  {'name': 'The Waterman',
#   'familyFriendly': 'no',
#   'eatType': None,
#   'food': 'Fast food',
#   'priceRange': 'moderate',
#   'near': None,
#   'area': 'riverside',
#   'customer rating': '3 out of 5'},
#  {'name': 'The Olive Grove',
#   'familyFriendly': 'yes',
#   'eatType': 'pub',
#   'food': 'French',
#   'priceRange': 'more than £30',
#   'near': None,
#   'area': 'city centre',
#   'customer rating': None},
#  {'name': 'Fitzbillies',
#   'familyFriendly': 'no',
#   'eatType': 'coffee shop',
#   'food': 'Indian',
#   'priceRange': '£20-25',
#   'near': None,
#   'area': 'city centre',
#   'customer rating': 'high'},
#  {'name': 'Wildwood',
#   'familyFriendly': None,
#   'eatType': 'pub',
#   'food': 'Italian',
#   'priceRange': '£20-25',
#   'near': None,
#   'area': None,
#   'customer rating': 'high'},
#  {'name': 'Fitzbillies',
#   'familyFriendly': 'yes',
#   'eatType': 'coffee shop',
#   'food': 'Japanese',
#   'priceRange': 'more than £30',
#   'near': None,
#   'area': 'riverside',
#   'customer rating': 'low'},
#  {'name': 'Bibimbap House',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': 'Italian',
#   'priceRange': 'moderate',
#   'near': 'Clare Hall',
#   'area': 'riverside',
#   'customer rating': None},
#  {'name': 'The Waterman',
#   'familyFriendly': None,
#   'eatType': 'pub',
#   'food': 'Japanese',
#   'priceRange': None,
#   'near': None,
#   'area': 'riverside',
#   'customer rating': '5 out of 5'},
#  {'name': 'The Dumpling Tree',
#   'familyFriendly': None,
#   'eatType': 'restaurant',
#   'food': 'Fast food',
#   'priceRange': 'high',
#   'near': None,
#   'area': None,
#   'customer rating': None},
#  {'name': 'Taste of Cambridge',
#   'familyFriendly': 'yes',
#   'eatType': 'coffee shop',
#   'food': 'Japanese',
#   'priceRange': None,
#   'near': 'Crowne Plaza Hotel',
#   'area': 'riverside',
#   'customer rating': None},
#  {'name': 'The Wrestlers',
#   'familyFriendly': 'yes',
#   'eatType': None,
#   'food': 'French',
#   'priceRange': 'more than £30',
#   'near': None,
#   'area': None,
#   'customer rating': 'low'},
#  {'name': 'Fitzbillies',
#   'familyFriendly': 'yes',
#   'eatType': None,
#   'food': None,
#   'priceRange': 'moderate',
#   'near': 'Express by Holiday Inn',
#   'area': None,
#   'customer rating': '1 out of 5'},
#  {'name': 'Loch Fyne',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': 'Italian',
#   'priceRange': None,
#   'near': 'The Rice Boat',
#   'area': 'riverside',
#   'customer rating': 'low'},
#  {'name': 'Green Man',
#   'familyFriendly': None,
#   'eatType': 'pub',
#   'food': 'Indian',
#   'priceRange': None,
#   'near': 'Café Rouge',
#   'area': 'city centre',
#   'customer rating': None},
#  {'name': 'The Olive Grove',
#   'familyFriendly': 'no',
#   'eatType': 'pub',
#   'food': 'English',
#   'priceRange': 'high',
#   'near': None,
#   'area': 'riverside',
#   'customer rating': None},
#  {'name': 'The Waterman',
#   'familyFriendly': None,
#   'eatType': 'pub',
#   'food': 'Japanese',
#   'priceRange': None,
#   'near': None,
#   'area': 'riverside',
#   'customer rating': '3 out of 5'},
#  {'name': 'Midsummer House',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': 'Japanese',
#   'priceRange': 'cheap',
#   'near': 'All Bar One',
#   'area': None,
#   'customer rating': '5 out of 5'},
#  {'name': 'Clowns',
#   'familyFriendly': None,
#   'eatType': 'pub',
#   'food': None,
#   'priceRange': 'more than £30',
#   'near': None,
#   'area': 'riverside',
#   'customer rating': 'high'},
#  {'name': 'Travellers Rest Beefeater',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': None,
#   'priceRange': '£20-25',
#   'near': 'Café Adriatic',
#   'area': 'city centre',
#   'customer rating': 'high'},
#  {'name': 'The Golden Palace',
#   'familyFriendly': None,
#   'eatType': 'coffee shop',
#   'food': 'French',
#   'priceRange': 'cheap',
#   'near': None,
#   'area': 'riverside',
#   'customer rating': '5 out of 5'},
#  {'name': 'The Golden Curry',
#   'familyFriendly': 'yes',
#   'eatType': None,
#   'food': 'Fast food',
#   'priceRange': None,
#   'near': None,
#   'area': None,
#   'customer rating': '5 out of 5'},
#  {'name': 'Midsummer House',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': 'Japanese',
#   'priceRange': '£20-25',
#   'near': 'All Bar One',
#   'area': None,
#   'customer rating': 'high'},
#  {'name': 'Blue Spice',
#   'familyFriendly': 'yes',
#   'eatType': None,
#   'food': None,
#   'priceRange': 'less than £20',
#   'near': None,
#   'area': 'riverside',
#   'customer rating': 'average'},
#  {'name': 'The Golden Palace',
#   'familyFriendly': None,
#   'eatType': 'coffee shop',
#   'food': 'Indian',
#   'priceRange': 'moderate',
#   'near': None,
#   'area': 'riverside',
#   'customer rating': '1 out of 5'},
#  {'name': 'Strada',
#   'familyFriendly': 'yes',
#   'eatType': None,
#   'food': 'Chinese',
#   'priceRange': 'cheap',
#   'near': 'Rainbow Vegetarian Café',
#   'area': None,
#   'customer rating': 'average'},
#  {'name': 'Aromi',
#   'familyFriendly': None,
#   'eatType': 'restaurant',
#   'food': 'Fast food',
#   'priceRange': None,
#   'near': None,
#   'area': 'riverside',
#   'customer rating': None},
#  {'name': 'The Phoenix',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': 'Italian',
#   'priceRange': 'high',
#   'near': None,
#   'area': 'riverside',
#   'customer rating': 'average'},
#  {'name': 'Bibimbap House',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': 'Italian',
#   'priceRange': '£20-25',
#   'near': 'Clare Hall',
#   'area': 'riverside',
#   'customer rating': None},
#  {'name': 'The Olive Grove',
#   'familyFriendly': 'yes',
#   'eatType': 'pub',
#   'food': 'Indian',
#   'priceRange': 'high',
#   'near': None,
#   'area': 'riverside',
#   'customer rating': None},
#  {'name': 'The Golden Curry',
#   'familyFriendly': 'yes',
#   'eatType': None,
#   'food': 'Fast food',
#   'priceRange': None,
#   'near': None,
#   'area': None,
#   'customer rating': '5 out of 5'},
#  {'name': 'Cocum',
#   'familyFriendly': 'no',
#   'eatType': 'coffee shop',
#   'food': 'Fast food',
#   'priceRange': 'less than £20',
#   'near': None,
#   'area': None,
#   'customer rating': 'low'},
#  {'name': 'The Golden Curry',
#   'familyFriendly': 'yes',
#   'eatType': None,
#   'food': 'Japanese',
#   'priceRange': None,
#   'near': 'Café Rouge',
#   'area': 'riverside',
#   'customer rating': '1 out of 5'},
#  {'name': 'The Golden Curry',
#   'familyFriendly': 'yes',
#   'eatType': None,
#   'food': 'Japanese',
#   'priceRange': 'less than £20',
#   'near': 'The Bakers',
#   'area': None,
#   'customer rating': None},
#  {'name': 'Wildwood',
#   'familyFriendly': None,
#   'eatType': 'coffee shop',
#   'food': 'Japanese',
#   'priceRange': '£20-25',
#   'near': 'Ranch',
#   'area': None,
#   'customer rating': 'high'},
#  {'name': 'Cocum',
#   'familyFriendly': 'no',
#   'eatType': 'pub',
#   'food': None,
#   'priceRange': 'high',
#   'near': None,
#   'area': None,
#   'customer rating': '3 out of 5'},
#  {'name': 'The Golden Curry',
#   'familyFriendly': 'yes',
#   'eatType': None,
#   'food': 'Japanese',
#   'priceRange': 'less than £20',
#   'near': 'The Bakers',
#   'area': None,
#   'customer rating': None},
#  {'name': 'Fitzbillies',
#   'familyFriendly': 'yes',
#   'eatType': 'coffee shop',
#   'food': 'French',
#   'priceRange': '£20-25',
#   'near': None,
#   'area': 'riverside',
#   'customer rating': 'high'},
#  {'name': 'Strada',
#   'familyFriendly': 'yes',
#   'eatType': None,
#   'food': 'English',
#   'priceRange': 'moderate',
#   'near': 'Rainbow Vegetarian Café',
#   'area': None,
#   'customer rating': '1 out of 5'},
#  {'name': 'Zizzi',
#   'familyFriendly': 'no',
#   'eatType': 'pub',
#   'food': 'Chinese',
#   'priceRange': None,
#   'near': None,
#   'area': None,
#   'customer rating': 'average'},
#  {'name': 'Alimentum',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': 'Italian',
#   'priceRange': 'moderate',
#   'near': 'Yippee Noodle Bar',
#   'area': 'riverside',
#   'customer rating': '1 out of 5'},
#  {'name': 'Alimentum',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': 'English',
#   'priceRange': 'moderate',
#   'near': 'Yippee Noodle Bar',
#   'area': 'city centre',
#   'customer rating': '1 out of 5'},
#  {'name': 'The Golden Curry',
#   'familyFriendly': 'yes',
#   'eatType': None,
#   'food': 'Fast food',
#   'priceRange': 'less than £20',
#   'near': 'The Bakers',
#   'area': None,
#   'customer rating': None},
#  {'name': 'The Phoenix',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': 'Fast food',
#   'priceRange': 'moderate',
#   'near': None,
#   'area': 'riverside',
#   'customer rating': '1 out of 5'},
#  {'name': 'Strada',
#   'familyFriendly': 'yes',
#   'eatType': None,
#   'food': None,
#   'priceRange': 'less than £20',
#   'near': None,
#   'area': None,
#   'customer rating': 'average'},
#  {'name': 'Fitzbillies',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': 'Italian',
#   'priceRange': 'high',
#   'near': 'The Six Bells',
#   'area': None,
#   'customer rating': None},
#  {'name': 'The Phoenix',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': 'English',
#   'priceRange': 'more than £30',
#   'near': None,
#   'area': 'riverside',
#   'customer rating': 'high'},
#  {'name': 'Fitzbillies',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': None,
#   'priceRange': 'less than £20',
#   'near': 'Rainbow Vegetarian Café',
#   'area': None,
#   'customer rating': None},
#  {'name': 'The Rice Boat',
#   'familyFriendly': 'yes',
#   'eatType': None,
#   'food': 'Japanese',
#   'priceRange': None,
#   'near': None,
#   'area': 'riverside',
#   'customer rating': '5 out of 5'},
#  {'name': 'Browns Cambridge',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': 'Fast food',
#   'priceRange': 'more than £30',
#   'near': None,
#   'area': None,
#   'customer rating': 'low'},
#  {'name': 'Travellers Rest Beefeater',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': None,
#   'priceRange': 'less than £20',
#   'near': 'Café Adriatic',
#   'area': 'riverside',
#   'customer rating': 'average'},
#  {'name': 'The Vaults',
#   'familyFriendly': None,
#   'eatType': 'coffee shop',
#   'food': None,
#   'priceRange': 'more than £30',
#   'near': 'Café Brazil',
#   'area': 'riverside',
#   'customer rating': 'high'},
#  {'name': 'Cotto',
#   'familyFriendly': 'yes',
#   'eatType': None,
#   'food': 'French',
#   'priceRange': None,
#   'near': 'Ranch',
#   'area': None,
#   'customer rating': 'average'},
#  {'name': 'The Punter',
#   'familyFriendly': 'no',
#   'eatType': None,
#   'food': None,
#   'priceRange': 'less than £20',
#   'near': 'The Portland Arms',
#   'area': 'riverside',
#   'customer rating': None},
#  {'name': 'The Golden Curry',
#   'familyFriendly': 'yes',
#   'eatType': None,
#   'food': 'Italian',
#   'priceRange': None,
#   'near': 'Café Rouge',
#   'area': 'city centre',
#   'customer rating': 'low'},
#  {'name': 'Wildwood',
#   'familyFriendly': None,
#   'eatType': 'coffee shop',
#   'food': 'Japanese',
#   'priceRange': 'less than £20',
#   'near': 'Ranch',
#   'area': None,
#   'customer rating': 'average'},
#  {'name': 'Alimentum',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': 'Chinese',
#   'priceRange': 'high',
#   'near': 'Yippee Noodle Bar',
#   'area': 'city centre',
#   'customer rating': '1 out of 5'},
#  {'name': 'The Golden Curry',
#   'familyFriendly': 'no',
#   'eatType': None,
#   'food': None,
#   'priceRange': None,
#   'near': 'The Six Bells',
#   'area': None,
#   'customer rating': None},
#  {'name': 'Alimentum',
#   'familyFriendly': 'yes',
#   'eatType': None,
#   'food': 'Japanese',
#   'priceRange': '£20-25',
#   'near': None,
#   'area': 'riverside',
# ...
#   'near': 'Express by Holiday Inn',
#   'area': 'riverside',
#   'customer rating': '5 out of 5'},
#  {'name': 'Strada',
#   'familyFriendly': None,
#   'eatType': 'pub',
#   'food': 'Italian',
#   'priceRange': None,
#   'near': 'Yippee Noodle Bar',
#   'area': None,
#   'customer rating': 'average'},
#  {'name': 'Giraffe',
#   'familyFriendly': 'no',
#   'eatType': 'pub',
#   'food': 'Japanese',
#   'priceRange': None,
#   'near': None,
#   'area': 'riverside',
#   'customer rating': None},
#  {'name': 'Browns Cambridge',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': None,
#   'priceRange': 'cheap',
#   'near': None,
#   'area': None,
#   'customer rating': '5 out of 5'},
#  {'name': 'The Wrestlers',
#   'familyFriendly': 'no',
#   'eatType': 'coffee shop',
#   'food': 'Japanese',
#   'priceRange': 'moderate',
#   'near': 'Raja Indian Cuisine',
#   'area': 'riverside',
#   'customer rating': None},
#  {'name': 'The Rice Boat',
#   'familyFriendly': 'no',
#   'eatType': None,
#   'food': 'Italian',
#   'priceRange': None,
#   'near': None,
#   'area': 'riverside',
#   'customer rating': '5 out of 5'},
#  {'name': 'Green Man',
#   'familyFriendly': 'no',
#   'eatType': None,
#   'food': None,
#   'priceRange': 'moderate',
#   'near': None,
#   'area': 'riverside',
#   'customer rating': None},
#  {'name': 'Midsummer House',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': 'English',
#   'priceRange': 'moderate',
#   'near': 'All Bar One',
#   'area': None,
#   'customer rating': '1 out of 5'},
#  {'name': 'The Dumpling Tree',
#   'familyFriendly': None,
#   'eatType': 'restaurant',
#   'food': 'French',
#   'priceRange': '£20-25',
#   'near': None,
#   'area': None,
#   'customer rating': None},
#  {'name': 'Browns Cambridge',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': None,
#   'priceRange': 'moderate',
#   'near': None,
#   'area': None,
#   'customer rating': '3 out of 5'},
#  {'name': 'The Rice Boat',
#   'familyFriendly': 'no',
#   'eatType': None,
#   'food': 'French',
#   'priceRange': None,
#   'near': None,
#   'area': 'riverside',
#   'customer rating': 'low'},
#  {'name': 'Cotto',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': 'Indian',
#   'priceRange': None,
#   'near': 'Café Rouge',
#   'area': None,
#   'customer rating': None},
#  {'name': 'The Punter',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': 'Japanese',
#   'priceRange': 'more than £30',
#   'near': None,
#   'area': None,
#   'customer rating': None},
#  {'name': 'The Rice Boat',
#   'familyFriendly': 'no',
#   'eatType': None,
#   'food': 'French',
#   'priceRange': None,
#   'near': None,
#   'area': 'riverside',
#   'customer rating': 'low'},
#  {'name': 'The Golden Palace',
#   'familyFriendly': None,
#   'eatType': 'coffee shop',
#   'food': 'French',
#   'priceRange': 'more than £30',
#   'near': None,
#   'area': 'riverside',
#   'customer rating': 'low'},
#  {'name': 'The Eagle',
#   'familyFriendly': 'yes',
#   'eatType': 'coffee shop',
#   'food': 'Indian',
#   'priceRange': 'moderate',
#   'near': 'Burger King',
#   'area': 'riverside',
#   'customer rating': '3 out of 5'},
#  {'name': 'Travellers Rest Beefeater',
#   'familyFriendly': 'yes',
#   'eatType': 'restaurant',
#   'food': None,
#   'priceRange': 'more than £30',
#   'near': None,
#   'area': None,
#   'customer rating': None},
#  {'name': 'The Twenty Two',
#   'familyFriendly': 'yes',
#   'eatType': None,
#   'food': 'Italian',
#   'priceRange': None,
#   'near': None,
#   'area': None,
#   'customer rating': None},
#  {'name': 'The Punter',
#   'familyFriendly': 'no',
#   'eatType': 'coffee shop',
#   'food': 'French',
#   'priceRange': 'moderate',
#   'near': 'Café Sicilia',
#   'area': None,
#   'customer rating': '1 out of 5'},
#  {'name': 'Browns Cambridge',
#   'familyFriendly': 'no',
#   'eatType': None,
#   'food': 'Fast food',
#   'priceRange': None,
#   'near': 'The Sorrento',
#   'area': 'riverside',
#   'customer rating': None},
#  {'name': 'Fitzbillies',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': None,
#   'priceRange': 'less than £20',
#   'near': 'Rainbow Vegetarian Café',
#   'area': None,
#   'customer rating': None},
#  {'name': 'Fitzbillies',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': 'Indian',
#   'priceRange': 'cheap',
#   'near': 'The Six Bells',
#   'area': None,
#   'customer rating': None},
#  {'name': 'The Wrestlers',
#   'familyFriendly': 'no',
#   'eatType': 'coffee shop',
#   'food': 'Indian',
#   'priceRange': 'less than £20',
#   'near': 'Raja Indian Cuisine',
#   'area': 'city centre',
#   'customer rating': None},
#  {'name': 'The Olive Grove',
#   'familyFriendly': 'no',
#   'eatType': 'pub',
#   'food': 'Fast food',
#   'priceRange': 'high',
#   'near': None,
#   'area': 'city centre',
#   'customer rating': None},
#  {'name': 'Fitzbillies',
#   'familyFriendly': 'yes',
#   'eatType': 'coffee shop',
#   'food': 'Japanese',
#   'priceRange': 'less than £20',
#   'near': None,
#   'area': 'riverside',
#   'customer rating': 'low'},
#  {'name': 'The Golden Curry',
#   'familyFriendly': 'yes',
#   'eatType': None,
#   'food': 'Japanese',
#   'priceRange': '£20-25',
#   'near': 'The Bakers',
#   'area': None,
#   'customer rating': None},
#  {'name': 'The Mill',
#   'familyFriendly': None,
#   'eatType': 'pub',
#   'food': 'Japanese',
#   'priceRange': 'less than £20',
#   'near': None,
#   'area': 'riverside',
#   'customer rating': None},
#  {'name': 'The Olive Grove',
#   'familyFriendly': 'no',
#   'eatType': 'restaurant',
#   'food': None,
#   'priceRange': None,
#   'near': None,
#   'area': 'riverside',
#   'customer rating': None},
#  {'name': 'Fitzbillies',
#   'familyFriendly': 'no',
#   'eatType': 'coffee shop',
#   'food': 'Japanese',
#   'priceRange': 'less than £20',
#   'near': None,
#   'area': 'riverside',
#   'customer rating': 'low'},
#  {'name': 'The Waterman',
#   'familyFriendly': 'yes',
#   'eatType': None,
#   'food': 'French',
#   'priceRange': 'more than £30',
#   'near': None,
#   'area': 'riverside',
#   'customer rating': '5 out of 5'},
#  {'name': 'The Rice Boat',
#   'familyFriendly': 'yes',
#   'eatType': None,
#   'food': 'French',
#   'priceRange': None,
#   'near': None,
#   'area': 'city centre',
#   'customer rating': 'average'},
#  {'name': 'The Golden Palace',
#   'familyFriendly': None,
#   'eatType': 'coffee shop',
#   'food': 'Indian',
#   'priceRange': 'less than £20',
#   'near': None,
#   'area': 'riverside',
#   'customer rating': 'low'},
#  {'name': 'The Wrestlers',
#   'familyFriendly': 'yes',
#   'eatType': 'coffee shop',
#   'food': 'French',
#   'priceRange': 'more than £30',
#   'near': 'Raja Indian Cuisine',
#   'area': 'city centre',
#   'customer rating': None},
#  {'name': 'The Waterman',
#   'familyFriendly': 'no',
#   'eatType': None,
#   'food': 'Chinese',
#   'priceRange': 'moderate',
#   'near': None,
#   'area': 'city centre',
#   'customer rating': '1 out of 5'},
#  {'name': 'Strada',
#   'familyFriendly': 'no',
#   'eatType': None,
#   'food': None,
#   'priceRange': 'moderate',
#   'near': None,
#   'area': None,
#   'customer rating': '1 out of 5'},
#  {'name': 'Green Man',
#   'familyFriendly': 'yes',
#   'eatType': None,
#   'food': 'Italian',
#   'priceRange': 'moderate',
#   'near': 'All Bar One',
#   'area': 'riverside',
#   'customer rating': None},
#  {'name': 'The Waterman',
#   'familyFriendly': 'no',
#   'eatType': None,
#   'food': 'Italian',
#   'priceRange': 'high',
#   'near': None,
#   'area': 'riverside',
#   'customer rating': '1 out of 5'},
#  {'name': 'Wildwood',
#   'familyFriendly': None,
#   'eatType': 'pub',
#   'food': 'Italian',
#   'priceRange': 'moderate',
#   'near': None,
#   'area': None,
#   'customer rating': '1 out of 5'},
#  {'name': 'The Waterman',
#   'familyFriendly': 'no',
#   'eatType': None,
#   'food': 'French',
#   'priceRange': 'less than £20',
#   'near': None,
#   'area': 'riverside',
#   'customer rating': 'average'},
#  {'name': 'Clowns',
#   'familyFriendly': None,
#   'eatType': 'pub',
#   'food': None,
#   'priceRange': 'moderate',
#   'near': None,
#   'area': 'city centre',
#   'customer rating': '1 out of 5'},
#  {'name': 'Browns Cambridge',
#   'familyFriendly': 'yes',
#   'eatType': 'coffee shop',
#   'food': 'Indian',
#   'priceRange': None,
#   'near': 'Crowne Plaza Hotel',
#   'area': 'city centre',
#   'customer rating': 'low'},
#  {'name': 'The Rice Boat',
#   'familyFriendly': 'no',
#   'eatType': None,
#   'food': 'Fast food',
#   'priceRange': 'more than £30',
#   'near': 'Express by Holiday Inn',
#   'area': 'city centre',
#   'customer rating': 'high'},
#  {'name': 'The Phoenix',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': 'Italian',
#   'priceRange': 'moderate',
#   'near': None,
#   'area': 'riverside',
#   'customer rating': '3 out of 5'},
#  {'name': 'The Mill',
#   'familyFriendly': None,
#   'eatType': 'pub',
#   'food': 'English',
#   'priceRange': 'high',
#   'near': None,
#   'area': 'riverside',
#   'customer rating': None},
#  {'name': 'The Plough',
#   'familyFriendly': 'yes',
#   'eatType': 'restaurant',
#   'food': None,
#   'priceRange': None,
#   'near': 'Express by Holiday Inn',
#   'area': None,
#   'customer rating': None},
#  {'name': 'The Mill',
#   'familyFriendly': None,
#   'eatType': 'coffee shop',
#   'food': 'French',
#   'priceRange': 'moderate',
#   'near': 'The Sorrento',
#   'area': 'city centre',
#   'customer rating': None},
#  {'name': 'The Twenty Two',
#   'familyFriendly': 'yes',
#   'eatType': None,
#   'food': None,
#   'priceRange': 'high',
#   'near': 'The Rice Boat',
#   'area': 'riverside',
#   'customer rating': '1 out of 5'},
#  {'name': 'Zizzi',
#   'familyFriendly': 'no',
#   'eatType': 'coffee shop',
#   'food': None,
#   'priceRange': '£20-25',
#   'near': None,
#   'area': 'city centre',
#   'customer rating': '3 out of 5'},
#  {'name': 'Zizzi',
#   'familyFriendly': 'no',
#   'eatType': 'pub',
#   'food': 'English',
#   'priceRange': None,
#   'near': None,
#   'area': None,
#   'customer rating': 'low'},
#  {'name': 'The Phoenix',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': 'Fast food',
#   'priceRange': 'high',
#   'near': None,
#   'area': 'riverside',
#   'customer rating': 'average'},
#  {'name': 'Cotto',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': None,
#   'priceRange': '£20-25',
#   'near': 'All Bar One',
#   'area': 'riverside',
#   'customer rating': None},
#  {'name': 'Zizzi',
#   'familyFriendly': 'yes',
#   'eatType': 'pub',
#   'food': 'English',
#   'priceRange': None,
#   'near': None,
#   'area': None,
#   'customer rating': 'high'},
#  {'name': 'Wildwood',
#   'familyFriendly': None,
#   'eatType': 'pub',
#   'food': 'English',
#   'priceRange': 'cheap',
#   'near': None,
#   'area': None,
#   'customer rating': '5 out of 5'},
#  {'name': 'The Wrestlers',
#   'familyFriendly': 'no',
#   'eatType': 'coffee shop',
#   'food': 'Italian',
#   'priceRange': 'less than £20',
#   'near': 'Raja Indian Cuisine',
#   'area': 'city centre',
#   'customer rating': None},
#  {'name': 'The Wrestlers',
#   'familyFriendly': 'yes',
#   'eatType': None,
#   'food': 'Fast food',
#   'priceRange': 'high',
#   'near': None,
#   'area': None,
#   'customer rating': '1 out of 5'},
#  {'name': 'Browns Cambridge',
#   'familyFriendly': 'yes',
#   'eatType': 'coffee shop',
#   'food': 'Fast food',
#   'priceRange': None,
#   'near': 'Crowne Plaza Hotel',
#   'area': 'riverside',
#   'customer rating': '5 out of 5'},
#  {'name': 'Giraffe',
#   'familyFriendly': 'no',
#   'eatType': 'pub',
#   'food': 'Fast food',
#   'priceRange': None,
#   'near': None,
#   'area': 'riverside',
#   'customer rating': None},
#  {'name': 'Bibimbap House',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': 'Chinese',
#   'priceRange': 'high',
#   'near': 'Clare Hall',
#   'area': 'riverside',
#   'customer rating': None},
#  {'name': 'The Golden Palace',
#   'familyFriendly': None,
#   'eatType': 'coffee shop',
#   'food': 'Fast food',
#   'priceRange': 'high',
#   'near': None,
#   'area': 'riverside',
#   'customer rating': '1 out of 5'},
#  {'name': 'Blue Spice',
#   'familyFriendly': 'yes',
#   'eatType': None,
#   'food': None,
#   'priceRange': 'high',
#   'near': None,
#   'area': 'riverside',
#   'customer rating': '1 out of 5'},
#  {'name': 'Aromi',
#   'familyFriendly': 'yes',
#   'eatType': 'coffee shop',
#   'food': 'Fast food',
#   'priceRange': None,
#   'near': None,
#   'area': 'riverside',
#   'customer rating': '1 out of 5'},
#  {'name': 'Browns Cambridge',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': 'English',
#   'priceRange': '£20-25',
#   'near': None,
#   'area': None,
#   'customer rating': 'high'},
#  {'name': 'Fitzbillies',
#   'familyFriendly': 'no',
#   'eatType': 'coffee shop',
#   'food': 'Indian',
#   'priceRange': 'high',
#   'near': None,
#   'area': 'riverside',
#   'customer rating': '1 out of 5'},
#  {'name': 'The Eagle',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': None,
#   'priceRange': 'cheap',
#   'near': None,
#   'area': 'city centre',
#   'customer rating': '5 out of 5'},
#  {'name': 'The Waterman',
#   'familyFriendly': 'yes',
#   'eatType': None,
#   'food': 'Italian',
#   'priceRange': None,
#   'near': 'Crowne Plaza Hotel',
#   'area': None,
#   'customer rating': None},
#  {'name': 'The Waterman',
#   'familyFriendly': None,
#   'eatType': 'pub',
#   'food': 'English',
#   'priceRange': None,
#   'near': None,
#   'area': 'city centre',
#   'customer rating': '5 out of 5'},
#  {'name': 'The Vaults',
#   'familyFriendly': None,
#   'eatType': 'coffee shop',
#   'food': None,
#   'priceRange': 'more than £30',
#   'near': 'Café Brazil',
#   'area': 'city centre',
#   'customer rating': 'low'},
#  {'name': 'The Rice Boat',
#   'familyFriendly': 'yes',
#   'eatType': None,
#   'food': 'Chinese',
#   'priceRange': None,
#   'near': None,
#   'area': 'riverside',
#   'customer rating': 'low'},
#  {'name': 'The Wrestlers',
#   'familyFriendly': 'yes',
#   'eatType': None,
#   'food': 'Chinese',
#   'priceRange': 'less than £20',
#   'near': None,
#   'area': None,
#   'customer rating': 'low'},
#  {'name': 'Loch Fyne',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': 'Japanese',
#   'priceRange': None,
#   'near': 'The Rice Boat',
#   'area': 'city centre',
#   'customer rating': 'low'},
#  {'name': 'The Cambridge Blue',
#   'familyFriendly': None,
#   'eatType': 'restaurant',
#   'food': 'Japanese',
#   'priceRange': None,
#   'near': None,
#   'area': None,
#   'customer rating': 'low'},
#  {'name': 'Fitzbillies',
#   'familyFriendly': 'yes',
#   'eatType': 'coffee shop',
#   'food': 'Japanese',
#   'priceRange': 'moderate',
#   'near': None,
#   'area': 'city centre',
#   'customer rating': '1 out of 5'},
#  {'name': 'Green Man',
#   'familyFriendly': 'yes',
#   'eatType': None,
#   'food': 'Japanese',
#   'priceRange': 'cheap',
#   'near': 'All Bar One',
#   'area': 'riverside',
#   'customer rating': None},
#  {'name': 'Zizzi',
#   'familyFriendly': 'yes',
#   'eatType': 'coffee shop',
#   'food': None,
#   'priceRange': 'more than £30',
#   'near': None,
#   'area': 'riverside',
#   'customer rating': 'high'},
#  {'name': 'Browns Cambridge',
#   'familyFriendly': 'no',
#   'eatType': 'coffee shop',
#   'food': 'Italian',
#   'priceRange': None,
#   'near': 'Crowne Plaza Hotel',
#   'area': 'riverside',
#   'customer rating': 'low'},
#  {'name': 'Fitzbillies',
#   'familyFriendly': 'no',
#   'eatType': 'coffee shop',
#   'food': 'Fast food',
#   'priceRange': 'moderate',
#   'near': None,
#   'area': 'riverside',
#   'customer rating': '1 out of 5'},
#  {'name': 'Blue Spice',
#   'familyFriendly': None,
#   'eatType': None,
#   'food': 'French',
#   'priceRange': '£20-25',
#   'near': None,
#   'area': 'riverside',
#   'customer rating': None},
#  {'name': 'The Rice Boat',
#   'familyFriendly': 'yes',
#   'eatType': None,
#   'food': 'Indian',
#   'priceRange': '£20-25',
#   'near': 'Express by Holiday Inn',
#   'area': 'city centre',
#   'customer rating': 'high'},
#  {'name': 'Wildwood',
#   'familyFriendly': 'yes',
#   'eatType': 'restaurant',
#   'food': None,
#   'priceRange': None,
#   'near': None,
#   'area': None,
#   'customer rating': None},
#  {'name': 'The Golden Curry',
#   'familyFriendly': 'yes',
#   'eatType': None,
#   'food': 'French',
#   'priceRange': None,
#   'near': 'Café Rouge',
#   'area': 'riverside',
#   'customer rating': '3 out of 5'},
#  {'name': 'The Twenty Two',
#   'familyFriendly': 'yes',
#   'eatType': None,
#   'food': None,
#   'priceRange': 'more than £30',
#   'near': 'The Rice Boat',
#   'area': 'city centre',
#   'customer rating': '5 out of 5'},
#  {'name': 'Zizzi',
#   'familyFriendly': 'yes',
#   'eatType': 'pub',
#   'food': 'Fast food',
#   'priceRange': None,
#   'near': None,
#   'area': None,
#   'customer rating': '3 out of 5'},
#  {'name': 'Alimentum',
#   'familyFriendly': 'no',
#   'eatType': None,
#   'food': 'English',
#   'priceRange': 'high',
#   'near': None,
#   'area': 'riverside',
#   'customer rating': None},
#  ...]

# %%
ref_dict = [process_e2e_text(data.iloc[i]['ref']) for i in range(len(data))]
ref_dict[0]
# Out:
# ['The',
#  'Vaults',
#  'pub',
#  'near',
#  'Café',
#  'Adriatic',
#  'has',
#  'a',
#  '5',
#  'star',
#  'rating',
#  '.',
#  'Prices',
#  'start',
#  'at',
#  '£30',
#  '.']

# %%
mr_df = pd.DataFrame.from_dict([process_e2e_mr(data.iloc[i]['mr']) for i in range(len(data))])

# %%
mr_df.describe(exclude=[None])
# Out:
#                  name familyFriendly      eatType      food priceRange  \
# count           42061          26295        20111     35126      29127
# unique             34              2            3         7          6
# top     The Rice Boat            yes  coffee shop  Japanese   moderate
# freq             2826          17564        10396      5996       5650
#
#               near       area customer rating
# count        20546      24716           28090
# unique          19          2               6
# top     Café Rouge  riverside         average
# freq          2052      16894            5495

# %%
references = [process_e2e_text(data.iloc[i]['ref']) for i in range(len(data))]

# %%
references_lens = [len(d) for d in references]
references_lens[:10]
# Out:
# [17, 26, 27, 29, 19, 30, 18, 30, 19, 27]

# %%
import matplotlib
matplotlib.rcParams.update({'font.size': 12})
plot_len_hist(references_lens, fname=DATA_LEN_HIST_FN)

# %%
# see what the unique values for each MR are
for colname in mr_df.columns:
    print(colname, ": ", mr_df[colname].unique())
# Out:
# name :  ['The Vaults' 'The Cambridge Blue' 'The Eagle' 'The Mill' 'Loch Fyne'
#  'Bibimbap House' 'The Rice Boat' 'The Wrestlers' 'Aromi' 'The Phoenix'
#  'Browns Cambridge' 'Taste of Cambridge' 'Cocum' 'The Dumpling Tree'
#  'The Punter' 'The Golden Curry' 'Alimentum' 'Midsummer House'
#  'Blue Spice' 'Strada' 'The Waterman' 'Zizzi' 'Green Man' 'Clowns'
#  'Giraffe' 'The Olive Grove' 'The Twenty Two' 'The Cricketers' 'Wildwood'
#  'The Golden Palace' 'The Plough' 'Cotto' 'Fitzbillies'
#  'Travellers Rest Beefeater']
# familyFriendly :  [None 'yes' 'no']
# eatType :  ['pub' 'coffee shop' None 'restaurant']
# food :  [None 'English' 'Japanese' 'French' 'Fast food' 'Italian' 'Indian'
#  'Chinese']
# priceRange :  ['more than £30' 'cheap' 'less than £20' '£20-25' None 'moderate' 'high']
# near :  ['Café Adriatic' 'Café Brazil' 'Burger King' 'The Sorrento'
#  'The Rice Boat' 'Clare Hall' None 'Raja Indian Cuisine' 'Café Rouge'
#  'Yippee Noodle Bar' 'The Portland Arms' 'All Bar One'
#  'Express by Holiday Inn' 'The Bakers' 'Café Sicilia' 'Avalon'
#  'The Six Bells' 'Ranch' 'Crowne Plaza Hotel' 'Rainbow Vegetarian Café']
# area :  [None 'riverside' 'city centre']
# customer rating :  ['5 out of 5' None 'low' 'high' 'average' '3 out of 5' '1 out of 5']

# %%
mr_df
# Out:
#                      name familyFriendly      eatType      food  \
# 0              The Vaults           None          pub      None
# 1      The Cambridge Blue           None          pub   English
# 2               The Eagle            yes  coffee shop  Japanese
# 3                The Mill           None  coffee shop    French
# 4               Loch Fyne           None         None    French
# ...                   ...            ...          ...       ...
# 42056       The Rice Boat            yes         None    Indian
# 42057          The Vaults           None   restaurant   Chinese
# 42058  The Cambridge Blue           None   restaurant   Italian
# 42059           The Eagle            yes  coffee shop   Italian
# 42060               Aromi           None   restaurant   English
#
#           priceRange                    near         area customer rating
# 0      more than £30           Café Adriatic         None      5 out of 5
# 1              cheap             Café Brazil         None            None
# 2      less than £20             Burger King    riverside             low
# 3             £20-25            The Sorrento    riverside            None
# 4               None           The Rice Boat    riverside            high
# ...              ...                     ...          ...             ...
# 42056          cheap  Express by Holiday Inn  city centre      5 out of 5
# 42057           None                    None         None            None
# 42058           None                    None         None            high
# 42059  less than £20             Burger King    riverside             low
# 42060           None                    None  city centre            None
#
# [42061 rows x 8 columns]
